# %%
import mlrose
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
import time
import random
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def import_data():
    df_ds1 = pd.read_csv("./data/winequality-red.csv", sep=";") # .append(pd.read_csv("winequality-white.csv", sep=";"))
    missing_values = ['?']
    df_ds2 = pd.read_csv("./data/breast-cancer-wisconsin.csv", sep=",",na_values = missing_values)
    df_ds2.fillna(method='ffill',inplace=True)
    X_ds1 = np.array(df_ds1.values[:,1:-1])
    y_ds1 = np.array(df_ds1.values[:,-1])
    y_ds1 = (y_ds1<7).astype(int)
    X_ds2 = np.array(df_ds2.values[:,1:-1])
    y_ds2 = np.array(df_ds2.values[:,-1])
    return X_ds1, y_ds1, X_ds2, y_ds2

# %%
def train_test(X, y):
    X_train, X_test, y_train, y_test = train_test_split(np.array(X),np.array(y), test_size=0.25)
    sc = preprocessing.StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    return X_train, X_test, y_train, y_test

# %%
def nn_learner(X_train, X_test, y_train, y_test):
    #clf_nn = MLPClassifier(hidden_layer_sizes=(10, 10,10), random_state=18, max_iter=1000)
    __clf_nn = MLPClassifier(hidden_layer_sizes=(20, 20,10),random_state=18)
    print(__clf_nn)
    __clf_nn.fit(X_train, y_train)
    y_pred = __clf_nn.predict(X_test)
    nn_accuracy = metrics.accuracy_score(y_test, y_pred)
    print('Accuracy of neural network without hyperparameter tuning is %.2f%%' % (nn_accuracy * 100))
    return __clf_nn

# %%
def __nn_analysis(algorithm,__hidden_layer,__learning_rate,max_iters,max_attempts, X_train, X_test, y_train, y_test,\
                    pop_size = 200, mutation_prob = 0.2,restarts =0,schedule=mlrose.GeomDecay(),random_state=None):

    if algorithm == 'simulated_annealing':
        nn_model1 = mlrose.NeuralNetwork(hidden_nodes =__hidden_layer, activation = 'relu', algorithm = algorithm,
                                max_iters = max_iters, bias = True, is_classifier = True, learning_rate = __learning_rate,
                                early_stopping=True,max_attempts=max_attempts,schedule=schedule,random_state=random_state)
    elif algorithm == 'genetic_alg':
        nn_model1 = mlrose.NeuralNetwork(hidden_nodes = __hidden_layer, activation = 'relu', algorithm = algorithm,
                                max_iters = max_iters, bias = True, is_classifier = True, learning_rate = __learning_rate,
                                early_stopping=True,max_attempts=max_attempts,\
                                pop_size = pop_size, mutation_prob = mutation_prob,random_state=random_state)
    elif algorithm == 'random_hill_climb':
        nn_model1 = mlrose.NeuralNetwork(hidden_nodes = __hidden_layer, activation = 'relu', algorithm = algorithm,
                                max_iters = max_iters, bias = True, is_classifier = True, learning_rate = __learning_rate,
                                early_stopping=True,max_attempts=max_attempts,restarts =restarts,random_state=random_state)
    elif algorithm == 'gradient_descent':
        nn_model1 = mlrose.NeuralNetwork(hidden_nodes = __hidden_layer, activation = 'relu', algorithm = algorithm,
                                max_iters = max_iters, bias = True, is_classifier = True, learning_rate = __learning_rate,
                                early_stopping=True, max_attempts=max_attempts,restarts =restarts,random_state=random_state)
        

    start_time_train = time.time()
    nn_model1.fit(X_train, y_train)
    end_time_train = time.time() - start_time_train
    
    # Predict labels for train set and assess accuracy
    y_train_pred = nn_model1.predict(X_train)
    y_train_accuracy = metrics.accuracy_score(y_train, y_train_pred)
    print('Training accuracy: ', y_train_accuracy)
    
    # Predict labels for test set and assess accuracy
    start_time_pred = time.time()
    y_test_pred = nn_model1.predict(X_test)
    end_time_pred = time.time() - start_time_pred
    
    y_test_accuracy = metrics.accuracy_score(y_test, y_test_pred)
    print('Test accuracy: ', y_test_accuracy)
    
    return y_train_accuracy, y_test_accuracy, end_time_train, end_time_pred

# %%
def train_nn_optimization(__hidden_layer,__learning_rate,max_attempts, X_train, X_test,y_train, y_test,\
                            __range=range(1000,10000,1000), pop_size=200, mutation_prob=0.2,restarts =0,schedule=mlrose.GeomDecay(),random_state=None):
    __nn_metrics = {}
    for algorithm in ['random_hill_climb', 'simulated_annealing', 'genetic_alg']:
        __train_accuracy_values, __test_accuracy_values,__train_time_values, __pred_time_values = [],[],[],[]
        for i in __range:
            __train_accuracy, __test_accuracy,__train_time, __pred_time = __nn_analysis(algorithm,__hidden_layer,__learning_rate,i,\
                                                                                          max_attempts, X_train, X_test, \
                                                                                          y_train, y_test,pop_size, \
                                                                                          mutation_prob,restarts,schedule,random_state)
            __train_accuracy_values.append(__train_accuracy)
            __test_accuracy_values.append(__test_accuracy)
            __train_time_values.append(__train_time)
            __pred_time_values.append(__pred_time)
        __nn_metrics[algorithm] = {'train_accuracy' : __train_accuracy_values, 'test_accuracy' : __test_accuracy_values, 'train_time' : __train_time_values,'pred_time' : __pred_time_values}
    return __nn_metrics

# %%
def plot_nn_optimization(plot_type,y_axis,results,x_label,y_label,title,filename):
    for algorithm in ['random_hill_climb', 'simulated_annealing', 'genetic_alg'] :
        if plot_type == 'train' :
            plt.plot(y_axis,np.array(results[algorithm]['train_accuracy']),label=algorithm)
        elif plot_type == 'test' :
            plt.plot(y_axis,np.array(results[algorithm]['test_accuracy']),label=algorithm)
        elif plot_type == 'time' :
            plt.plot(y_axis,np.array(results[algorithm]['train_time']),label=algorithm)
        elif plot_type == 'pred' :
            plt.plot(y_axis,np.array(results[algorithm]['pred_time']),label=algorithm)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend(loc='best')
    plt.savefig(filename)
    plt.show()
    plt.clf()

# %%
def train_nn_backdrop(__hidden_layer,__learning_rate,max_attempts, X_train, X_test,y_train, y_test,\
                        __range=range(1000,10000,1000), pop_size=200, mutation_prob=0.2,restarts =0,schedule=mlrose.GeomDecay(),random_state=None) :
    __nn_metrics = {}
    __train_accuracy_values, __test_accuracy_values,__train_time_values, __pred_time_values = [],[],[],[]
    algorithm = 'gradient_descent'
    for i in __range:
        __train_accuracy, __test_accuracy,__train_time, __pred_time = __nn_analysis(algorithm,__hidden_layer,__learning_rate,i,\
                                                                                          max_attempts, X_train, X_test, \
                                                                                          y_train, y_test,pop_size, \
                                                                                          mutation_prob,restarts,schedule,random_state)
        __train_accuracy_values.append(__train_accuracy)
        __test_accuracy_values.append(__test_accuracy)
        __train_time_values.append(__train_time)
        __pred_time_values.append(__pred_time)
    __nn_metrics[algorithm] = {'train_accuracy' : __train_accuracy_values, 'test_accuracy' : __test_accuracy_values, 'train_time' : __train_time_values,'pred_time' : __pred_time_values}
    return __nn_metrics

# %%
def plot_nn_backdrop(plot_type,y_axis,results,x_label,y_label,title,filename):
    algorithm = 'gradient_descent'
    if plot_type == 'train' :
        plt.plot(y_axis,np.array(results[algorithm]['train_accuracy']),label=algorithm)
    elif plot_type == 'test' :
        plt.plot(y_axis,np.array(results[algorithm]['test_accuracy']),label=algorithm)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend(loc='best')
    plt.savefig(filename)
    plt.show()
    plt.clf()

# %%
X_ds1, y_ds1, X_ds2, y_ds2 = import_data()
X_train, X_test, y_train, y_test = train_test(X_ds1, y_ds1)
__clf_nn = nn_learner(X_train, X_test, y_train, y_test)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20, 10), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=18, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)
# Accuracy of neural network without hyperparameter tuning is 87.00%
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
max_attempts = 100
__range=range(1000,100001,10000)
__schedule = mlrose.GeomDecay()
__hidden_layer =  list(__clf_nn.hidden_layer_sizes)
#__hidden_layer =  [5]
#__learning_rate = __clf_nn.learning_rate_init
__learning_rate = 0.1

__nn_metrics_optimization = train_nn_optimization(__hidden_layer,__learning_rate,max_attempts, X_train, X_test,y_train, y_test,__range, 200, 0.2,0,mlrose.GeomDecay(),18)
# Out:
# Training accuracy:  0.8615512927439533
# Test accuracy:  0.8475
# Training accuracy:  0.9541284403669725
# Test accuracy:  0.9
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.895
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.9
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.8365304420350292
# Test accuracy:  0.8025
# Training accuracy:  0.8974145120934112
# Test accuracy:  0.885
# Training accuracy:  0.8949124270225187
# Test accuracy:  0.875
# Training accuracy:  0.902418682235196
# Test accuracy:  0.8775
# Training accuracy:  0.9057547956630525
# Test accuracy:  0.8925
# Training accuracy:  0.914095079232694
# Test accuracy:  0.87
# Training accuracy:  0.8990825688073395
# Test accuracy:  0.87
# Training accuracy:  0.9090909090909091
# Test accuracy:  0.865
# Training accuracy:  0.8982485404503753
# Test accuracy:  0.865
# Training accuracy:  0.908256880733945
# Test accuracy:  0.8825
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725
# Training accuracy:  0.8773978315262719
# Test accuracy:  0.8725

# %%
plot_nn_optimization('train',__range,__nn_metrics_optimization,'Iterations','Accuracy','Optimization - Train Accuracy Vs Itevations','./plot/nn_optimization_train_accuracy_iterations10.png')
plot_nn_optimization('test',__range,__nn_metrics_optimization,'Iterations','Accuracy','Optimization - Test Accuracy Vs Itevations','./plot/nn_optimization_test_accuracy_iterations10.png')
plot_nn_optimization('time',__range,__nn_metrics_optimization,'Iterations','Time','Optimization - Computation Time Vs Itevations','./plot/nn_optimization_time_accuracy_iterations10.png')

# %%
max_attempts = 1000
__range=range(10,3000,5)
__hidden_layer =  list(__clf_nn.hidden_layer_sizes)
#__hidden_layer =  [5]
__learning_rate = __clf_nn.learning_rate_init
#__learning_rate = 0.01
__nn_metrics_backdrop = train_nn_backdrop(__hidden_layer,__learning_rate,max_attempts, X_train, X_test,y_train, y_test,__range, 200, 0.2,0,mlrose.GeomDecay(),18)
# Out:
# Training accuracy:  0.8565471226021685
# Test accuracy:  0.875
# Training accuracy:  0.8757297748123436
# Test accuracy:  0.8775
# Training accuracy:  0.8790658882402002
# Test accuracy:  0.8775
# Training accuracy:  0.8840700583819849
# Test accuracy:  0.875
# Training accuracy:  0.8840700583819849
# Test accuracy:  0.88
# Training accuracy:  0.8949124270225187
# Test accuracy:  0.8825
# Training accuracy:  0.8865721434528774
# Test accuracy:  0.8975
# Training accuracy:  0.8974145120934112
# Test accuracy:  0.885
# Training accuracy:  0.8999165971643036
# Test accuracy:  0.885
# Training accuracy:  0.902418682235196
# Test accuracy:  0.88
# Training accuracy:  0.902418682235196
# Test accuracy:  0.885
# Training accuracy:  0.8974145120934112
# Test accuracy:  0.8875
# Training accuracy:  0.9040867389491243
# Test accuracy:  0.8825
# Training accuracy:  0.896580483736447
# Test accuracy:  0.885
# Training accuracy:  0.9074228523769808
# Test accuracy:  0.89
# Training accuracy:  0.9049207673060884
# Test accuracy:  0.8875
# Training accuracy:  0.9099249374478732
# Test accuracy:  0.885
# Training accuracy:  0.9099249374478732
# Test accuracy:  0.885
# Training accuracy:  0.9107589658048374
# Test accuracy:  0.885
# Training accuracy:  0.9065888240200167
# Test accuracy:  0.8825
# Training accuracy:  0.908256880733945
# Test accuracy:  0.885
# Training accuracy:  0.9124270225187656
# Test accuracy:  0.8825
# Training accuracy:  0.9124270225187656
# Test accuracy:  0.8825
# Training accuracy:  0.9090909090909091
# Test accuracy:  0.8825
# Training accuracy:  0.914095079232694
# Test accuracy:  0.8825
# Training accuracy:  0.914095079232694
# Test accuracy:  0.8825
# Training accuracy:  0.9241034195162635
# Test accuracy:  0.8775
# Training accuracy:  0.920767306088407
# Test accuracy:  0.885
# Training accuracy:  0.920767306088407
# Test accuracy:  0.885
# Training accuracy:  0.926605504587156
# Test accuracy:  0.8825
# Training accuracy:  0.9190992493744787
# Test accuracy:  0.8775
# Training accuracy:  0.9190992493744787
# Test accuracy:  0.8775
# Training accuracy:  0.9274395329441201
# Test accuracy:  0.8775
# Training accuracy:  0.9274395329441201
# Test accuracy:  0.8775
# Training accuracy:  0.9157631359466222
# Test accuracy:  0.88
# Training accuracy:  0.9199332777314428
# Test accuracy:  0.8775
# Training accuracy:  0.9299416180150125
# Test accuracy:  0.885
# Training accuracy:  0.9299416180150125
# Test accuracy:  0.89
# Training accuracy:  0.9299416180150125
# Test accuracy:  0.89
# Training accuracy:  0.9299416180150125
# Test accuracy:  0.89
# Training accuracy:  0.9257714762301918
# Test accuracy:  0.885
# Training accuracy:  0.920767306088407
# Test accuracy:  0.885
# Training accuracy:  0.9407839866555463
# Test accuracy:  0.8875
# Training accuracy:  0.932443703085905
# Test accuracy:  0.89
# Training accuracy:  0.932443703085905
# Test accuracy:  0.89
# Training accuracy:  0.9349457881567973
# Test accuracy:  0.89
# Training accuracy:  0.9349457881567973
# Test accuracy:  0.89
# Training accuracy:  0.9357798165137615
# Test accuracy:  0.885
# Training accuracy:  0.9349457881567973
# Test accuracy:  0.885
# Training accuracy:  0.9349457881567973
# Test accuracy:  0.885
# Training accuracy:  0.9349457881567973
# Test accuracy:  0.895
# Training accuracy:  0.9349457881567973
# Test accuracy:  0.895
# Training accuracy:  0.9349457881567973
# Test accuracy:  0.895
# Training accuracy:  0.9382819015846539
# Test accuracy:  0.8925
# Training accuracy:  0.9499582985821518
# Test accuracy:  0.89
# Training accuracy:  0.9432860717264387
# Test accuracy:  0.89
# Training accuracy:  0.9432860717264387
# Test accuracy:  0.89
# Training accuracy:  0.9432860717264387
# Test accuracy:  0.89
# Training accuracy:  0.9432860717264387
# Test accuracy:  0.89
# Training accuracy:  0.9399499582985822
# Test accuracy:  0.885
# Training accuracy:  0.9441201000834029
# Test accuracy:  0.8825
# Training accuracy:  0.9407839866555463
# Test accuracy:  0.89
# Training accuracy:  0.9457881567973311
# Test accuracy:  0.8825
# Training accuracy:  0.9457881567973311
# Test accuracy:  0.8825
# Training accuracy:  0.9457881567973311
# Test accuracy:  0.8825
# Training accuracy:  0.9457881567973311
# Test accuracy:  0.8825
# Training accuracy:  0.9457881567973311
# Test accuracy:  0.8825
# Training accuracy:  0.9549624687239366
# Test accuracy:  0.8925
# Training accuracy:  0.9557964970809008
# Test accuracy:  0.885
# Training accuracy:  0.950792326939116
# Test accuracy:  0.8875
# Training accuracy:  0.950792326939116
# Test accuracy:  0.8875
# Training accuracy:  0.950792326939116
# Test accuracy:  0.8875
# Training accuracy:  0.9566305254378649
# Test accuracy:  0.895
# Training accuracy:  0.9566305254378649
# Test accuracy:  0.895
# Training accuracy:  0.950792326939116
# Test accuracy:  0.8875
# Training accuracy:  0.9566305254378649
# Test accuracy:  0.8875
# Training accuracy:  0.9566305254378649
# Test accuracy:  0.8875
# Training accuracy:  0.9599666388657214
# Test accuracy:  0.8825
# Training accuracy:  0.9582985821517932
# Test accuracy:  0.8875
# Training accuracy:  0.9532944120100083
# Test accuracy:  0.885
# Training accuracy:  0.9532944120100083
# Test accuracy:  0.885
# Training accuracy:  0.9532944120100083
# Test accuracy:  0.885
# Training accuracy:  0.9532944120100083
# Test accuracy:  0.885
# Training accuracy:  0.9599666388657214
# Test accuracy:  0.8875
# Training accuracy:  0.9599666388657214
# Test accuracy:  0.8875
# Training accuracy:  0.9599666388657214
# Test accuracy:  0.8875
# Training accuracy:  0.9599666388657214
# Test accuracy:  0.8875
# Training accuracy:  0.9641367806505421
# Test accuracy:  0.8875
# Training accuracy:  0.957464553794829
# Test accuracy:  0.8825
# Training accuracy:  0.9608006672226855
# Test accuracy:  0.885
# Training accuracy:  0.9599666388657214
# Test accuracy:  0.885
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8825
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8825
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8825
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8825
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8825
# Training accuracy:  0.9641367806505421
# Test accuracy:  0.88
# Training accuracy:  0.9641367806505421
# Test accuracy:  0.88
# Training accuracy:  0.963302752293578
# Test accuracy:  0.8825
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9716430358632193
# Test accuracy:  0.9
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8875
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8875
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8875
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8875
# Training accuracy:  0.9658048373644704
# Test accuracy:  0.8875
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8975
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8975
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8925
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8925
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8925
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8925
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8925
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8875
# Training accuracy:  0.9741451209341118
# Test accuracy:  0.89
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.885
# Training accuracy:  0.97581317764804
# Test accuracy:  0.895
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.89
# Training accuracy:  0.9791492910758965
# Test accuracy:  0.8875
# Training accuracy:  0.97581317764804
# Test accuracy:  0.89
# Training accuracy:  0.97581317764804
# Test accuracy:  0.8875
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.88
# Training accuracy:  0.9749791492910759
# Test accuracy:  0.8875
# Training accuracy:  0.9808173477898249
# Test accuracy:  0.8875
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.9849874895746455
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.9791492910758965
# Test accuracy:  0.8875
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8875
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8925
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.885
# Training accuracy:  0.9833194328607172
# Test accuracy:  0.88
# Training accuracy:  0.9833194328607172
# Test accuracy:  0.8775
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.8825
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.8825
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.8825
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.8825
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.8825
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.88
# Training accuracy:  0.9833194328607172
# Test accuracy:  0.885
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.88
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.88
# Training accuracy:  0.981651376146789
# Test accuracy:  0.885
# Training accuracy:  0.981651376146789
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.88
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.8825
# Training accuracy:  0.9841534612176814
# Test accuracy:  0.8825
# Training accuracy:  0.981651376146789
# Test accuracy:  0.885
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8775
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8775
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8775
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8775
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8775
# Training accuracy:  0.9849874895746455
# Test accuracy:  0.8875
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8875
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.8875
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.89
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.8875
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.89
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.89
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.89
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.89
# Training accuracy:  0.9858215179316097
# Test accuracy:  0.89
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.981651376146789
# Test accuracy:  0.8975
# Training accuracy:  0.9883236030025021
# Test accuracy:  0.8925
# Training accuracy:  0.9866555462885738
# Test accuracy:  0.8975
# Training accuracy:  0.9883236030025021
# Test accuracy:  0.8975
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9824854045037531
# Test accuracy:  0.9
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8925
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.9
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.8975
# Training accuracy:  0.9891576313594662
# Test accuracy:  0.895
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9916597164303587
# Test accuracy:  0.8925
# Training accuracy:  0.9924937447873228
# Test accuracy:  0.895
# Training accuracy:  0.9908256880733946
# Test accuracy:  0.8925
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9924937447873228
# Test accuracy:  0.8925
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9025
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.9899916597164303
# Test accuracy:  0.8975
# Training accuracy:  0.994161801501251
# Test accuracy:  0.91
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9075
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9075
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9075
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9075
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.9025
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.9025
# Training accuracy:  0.9933277731442869
# Test accuracy:  0.9025
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.9025
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.9025
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.9025
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.9025
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.9025
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.895
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9949958298582152
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9966638865721434
# Test accuracy:  0.8975
# Training accuracy:  0.9958298582151793
# Test accuracy:  0.8975

# %%
plot_nn_backdrop('train',__range,__nn_metrics_backdrop,'Iterations','Accuracy','Backprop - Train Accuracy Vs Itevations','./plot/nn_backprop_train_accuracy_iterations10.png')
plot_nn_backdrop('test',__range,__nn_metrics_backdrop,'Iterations','Accuracy','Backprop - Test Accuracy Vs Itevations','./plot/nn_backprop_test_accuracy_iterations10.png')
